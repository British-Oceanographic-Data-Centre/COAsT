# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import xarray as xr
import cartopy.crs as ccrs
from matplotlib import pyplot as plt

# %%
ds = xr.tutorial.open_dataset("rasm").load()

# %%
print(ds.xc.attrs)
print(ds.yc.attrs)
# Out:
# {'long_name': 'longitude of grid cell center', 'units': 'degrees_east'}
# {'long_name': 'latitude of grid cell center', 'units': 'degrees_north'}

# %%
ds.y
# Out:
# <xarray.DataArray 'y' (y: 205)>
# array([  0,   1,   2, ..., 202, 203, 204])
# Dimensions without coordinates: y

# %%
ds.x
# Out:
# <xarray.DataArray 'x' (x: 275)>
# array([  0,   1,   2, ..., 272, 273, 274])
# Dimensions without coordinates: x
